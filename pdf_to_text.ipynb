# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image

pdf_path = r'C:\Users\kotof\Sci_Prog\Sci_Prog\Lab_7\task.pdf'

pages = convert_from_path(pdf_path)

for page_num, page in enumerate(pages, start=1):

    text = pytesseract.image_to_string(page, lang='eng') 
    
    print(f"----- Страница {page_num} -----")
    print(text)
    print("\n")
# Out:
# ----- Страница 1 -----
# rpaduKknu
#
# BKuIOUNTe *KypHaMMpoBaHnKe padsorTEl.
#
# >> diary on
#
# Ilapametpuueckne rpa@uKkn
# TlapamMetpuueckve ypaBHeHUa AIT UAKMOMABI:
# x =r(t—sin(t)), y = r(1 — cos(t)).
#
# Tlocrpoum rpa@uKk Tpéx MepvosoB IMKAOUAbI pagnuyca 2. Pemenne.
# Tlockombky Mepvog, 27, HaM HyKHO, UTOGOHI MapameTp 6b B Ipegemax
# 0 < ¢t < 67 g7a Tpéex NoNHEIX WMKIOB. OlpezemumM Mapametp t Kak
# BeKTOP B 3TOM AMallazoHe, 3ATeM MbI BLIUMCIUM x UY.
#
# >> t = Linspace (0,6*pi,50);
# >> r= 2;
#
# >> x = r*(t-sin(t));
#
# >> y = r*(1-cos(t));
#
# >> plot (x,y)
#
# >> axis('equal');
#
# >> axis([@ 12*pi @ 4])
#
# >> savefig cycloid.pdf
#
# >> print -dpdf cycloid.pdf
# >> print -dpng cycloid.png
#
#
#
# ----- Страница 2 -----
# TlonspHbie KOOpaMHarTbI
#
# Tpaduxku B NosApHBIX KOOPAMHaTax CTpPOATCA aHAIOTMUHbIM OGpa3zom. [ia
#
# oyHKUMM
# r= f()
#
# MbI HaudUHAaeM C OlIpesesleHuna He3aBUcumMon llepemMeHHoi v, 3aTeM BbI-
# uncisem 7. UTOObI TIOCTPOUTb rpagnk, MBI BBIUUCIUM ZX UY, UCIOJIb3yeM
# CcTaHJapTHoe TIpeoOpa30BaHne KOOpAUHaT
#
# x =rcos(v),y =rsin(V),
#
# 3aTeM IIOCTPOMM rpa@nuk B OCAX LY.
# Tlocrpomum yautky Iackanst
#
# r= 1 —2sin(v).
#
# >> theta = Linspace (0,2*pi,100);
# >> r = 1-2*sin(theta);
#
# >> x=r.*cos(theta);
#
# >> y = r.*sin(theta);
#
# >> plot (x,y)
#
# >> print -dpdf Limacon.pdf
#
# >> print -dpng lLimacon.png
#
# TakoXe MOXKHO IOCTpOUTb PyHKIUM1O
#
# r= fv)
# B TIOJIAPHBIX OCAX, UCHOJIb3yA KOMAaHAY polar.
#
# >> theta = Linspace(@,2*pi,50);
# >> r = 1-2*sin(theta);
#
# >> polar(theta,r)
#
# >> print -dpdf Limacon-polar.pdf
# >> print -dpng lLimacon-polar.png
#
#
#
# ----- Страница 3 -----
# Tpagduku HeABHbIX PyYHKUMi
#
# Tlyctb HYKHO NOCTPOUTb yHKNH0, HexABHO olpeyenéHHyto0 ypaBHeHviem
#
# Bua
#
# f(x,y) = 0.
# Campi’ mpoctoi cnoco6 cyenaTb 3TO B Octave — C MOMOIIbIO KOMaHbI
# ezplot.
#
# Tlocrpoum kKpuByio, ollpeseisemylo ypaBHeHueM
#
# 2
#
# x? —aytaety’
#
# y=1.
#
# Uro6pi ompeyemmt dyHkym B Buge f(x, y) = 0, BBryTem 1 13 O6enx
# yacTei ypaBHeHus. 3azannm pyHKUMo B Bue A-dyHKUMM.
#
# >> £ = @(X,y) -x.42-x. *ytxty.42-y-1
# @(x, y) -x .72-x .*ytxty A2-y-1
#
# Tlocrpoum rpaduk.
#
# >> ezplot(f)
# >> print -dpdf impl1.pdf
#
# Havimém ypaBHeHuve KacaTeIbHOM K rpa@uky OKpyKHOCTU
# (x — 2)? +y? = 25
#
# B TouKe (—1, 4). Mocrpoum rpaduK oKpyKHOCTM uM KacaTebHoit.
# Yro6bl MOcTpouTb Kpyr, CHavasla OMpesesMM ero Kak byHKUVMIO BUA
# f(x,y) = 0. 3anagqum byHKuy B Buge A-dyHKuMn.
#
# >> £f = @(%.y) (%-2).424+y.42-25;
#
# Llentp kpyra Haxogtca B TouKe (2, 0), a paguyc paBex 5. 3azanm ocu
# Halllero rpadukKa Tak, YTOObI OHM HECKOJIbKO MpeBOCXOAMIM OKPyKHOCTb.
#
# >> ezplot(f£, [-6 10 -8 8])
#
#
#
# ----- Страница 4 -----
# VUcnomb3ys ipaBusio AMddepeHuMpoBaHua HeABHOM yHKUMNU, HaMTEM
#
# ya?
# y
# B rouxe (—1, 4) wmeem
# Waa = = 7
# Takum o6pa30M, ypaBHeHne KacaTembHOM AMHUNM GyeT UMeTb BU:
# 3 3 19
#
# Tlocrpoum rpadux.
#
# >> x = [-6:10];
#
# >> y 3/4*x+19/4;
#
# >> hold on
#
# >> plot(x,y,'r--')
#
# >> print -dpdf impl2.pdf
#
# KomimieKCHble aicia
#
# Hycrp z; = 1+ 22, 2, = 2 — 32. 3amuuiem ocHoBHble apupMetuyeckne
# ollepalimu c STUMU UMcHaMn.
#
# >> z1=14+2*i;
#
# >> z2=2-3*i;
#
# >> z1+z2
#
# ans = 3 - li
#
# >> z1-z2
#
# ans = -1 + 5i
#
# >> z1*z2
#
# ans = 8 + 1i
#
# >> z1/z2
#
# ans = -0@.30769 + 0.53846i
#
#
#
# ----- Страница 5 -----
# MBI MOxKeM MOCTpOMTb rpa@uUK B KOMIVIeKCHOM MIOCKOCTN, MCIOuIb3yA
# KOMaHAy compass.
#
# Tycrb 2, = 14-22, z. = 2—32.locrpoum rpa@uxn 21, 2, Uz, +2+2
# B KOMIMJI€KCHOM TWIOCKOCTU.
#
# >> clf
# >> zi = 14+2*i;
# >> z2 = 2-3*i;
#
# >> compass(z1, 'b')
#
# >> compass(z1,'b')
#
# >> hold on
#
# >> compass(z2,'r')
#
# >> compass(z1+z2,'k--')
#
# >> legend('z_1','z_2','z_1+z_2')
# >> print -dpdf complex.pdf
#
# VWnorga Octave MoxeT HeOKMDAHHO BbILaTb CTpaHHble pe3yibTaTbl 1A
# KOMIUIeKCHBIX ucen. Hanpumep, Baruncnum \/—8:
#
# >> (-8)*(1/3)
# ans = 1.0000 + 1.73211
#
# Oxugaicd OTBET —2, MbI TAKKE MOXKEM JIeTKO MpOBepNTb, ATO Ky6 WaH-
# HOLO OTBeTa JeMCTBUTeIbHO paBeH —8 (10 KpaiiHem Mepe, JO HeKOTOpOK
# He3HaUUTeIbHOM OMIMOKM OKpyrieHus):
#
# >> ans%3
# ans = -8.0000e+00 + 2.2204e-15i
#
# Ha caMoM jee cylijecTByeT Tp Kky6mueckux KOpHs 43 —8, v0 yMolI-
# yaHuio Octave BO3BpalllaeT TOT, Y KOTOPOrO HAMMeHbILNMM apryMeHT (yroll).
# Ec HaM MIpocTo HyKeH JeMCTBUTeIbHBIM KOpeHb, MbI MOKeM UCIIONIb30-
# BaTb KoMaHgy nthroot.
#
# >> nthroot(-8,3)
# ans = -2
#
#
#
# ----- Страница 6 -----
# CnemMaibHble PyHKUMM
#
# B Octave ZocTyNHO MHOPO cielMasIbHbIX PYHKUMM, TAKMX Kak PYHKUMM
# Beccena (besseL), PyHKUMA oMmM6oK (erf), ramMa-yHKIMA (gamma).
# TamMa-yHKUMA OMpeyeisercsa Kak
#
# r(e)= | t? edt.
# 0
#
# OTO pacliMpeHue dakTopmasia, MOCKONIbKy id HaTypasIbHbIX UUcel nN
# TaMMa-QyHKUMA yHOBIeETBOpAeT COOTHOLIEHMIO
#
# I'(n) = (n—1)!
#
# Tlocrpomm dynxumn C(x + 1) un! a ogHom rpadute.
# 3aqaqum 3HaveHna aprymenta x © [—5, 5] aaa ramma-hyHKun u
# n = 0,1, 2,3, 4,5 gia baxropuana.
#
# >> n=[0:1:5];
#
# >> x = Linspace(-5,5,500);
#
# >> plot(n, factorial(n), '*',x,gamma(x+1))
# >> clf
#
# >> plot(n,factorial(n),'*',x,gamma(xt+1))
# >> axis([-5 6 -10 25]);
#
# >> grid on;
#
# >> legend('n!', 'gamma(nt+1)')
#
# >> print -dpdf gamma.pdf
#
# O6paTuTe BHMMaHMe Ha BepTMKaJIbHble aCMMITOTHI Ha rpaduKe B palt-
# OHe OTPMUaTeIbHbIX WesIbIX UUceN. OHM He ABJIAIOTCA UCTUHHOM YacTbIo
# Tpa@uka. ITO apTedakTbl BbIUMcIeHUsa. ECM MbI XOTMM UX yCTpaHMTb,
# MBI JOJDKHbI pa3qeUTb oblacTb 3HaveHUM Ha OTTEMbHbIe MHTepBasIbI. ITO
# “aét Gonee TOUHBIM rpapuK.
#
# >> clf
#
# >> x1 = Linspace(-5,-4,500);
# >> x2 Linspace(-4,-3,500);
# >> x3 = Linspace(-3,-2,500);
# >> x4 Linspace(-2,-1,500);
#
# 6
#
#
#
# ----- Страница 7 -----
# >>
# >>
# >>
# >>
# >>
# >>
# >>
# >>
# >>
# >>
# >>
#
# >>
#
# x5 = Linspace(-1,5,500);
# plot¢(x1,gamma(x1i+1))
# hold on
# plot(x2,gamma(x2+1))
# plot(x3,gamma(x3+1))
# plot( x4, gamma(x4+1))
# plotc(x5,gamma(x5+1))
# axis([-5 6 -1@ 25]);
# plot (n,factorial(n),'*')
# Legend¢('n!',"\\Gamma(n+1)")
# print -dpdf gamma2.pdf
#
# Bxk0"NTe *KypHaIMpoBaHve.
#
# diary off
#
#
#
# ----- Страница 8 -----
# sanaHne
#
# ¢ Cyenavitre oruét 0 a6opaTopHon paoore B dopmate Markdown.
#
# ¢ B KauecTBe oTBeTa IIpocb6a MpesOcTaBUTb OTYETHI B 3 CPopMarTax:
# pdf, docx u md (B apxmBe, MOCKONIbKy OH JOUDKEH COJepKaTb CKPUH-
# motbt, Makefile 1 7.1.)
